# %% [markdown]
# # Practical Regression Assignment
# Questions 6-9

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
x=np.array([1,2,3,4,5]).reshape(-1,1)
y=np.array([2.1,4.3,6.1,7.9,10.2])
model=LinearRegression().fit(x,y)
print("Slope:",model.coef_[0])
print("Intercept:",model.intercept_)
plt.scatter(x,y)
plt.plot(x,model.predict(x))
plt.show()
# Out:
# Slope: 2.01
# Intercept: 0.08

# %% [markdown]
# ## Question 7

# %%
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.linear_model import LinearRegression
df=pd.DataFrame({"Area":[1200,1500,1800,2000],"Rooms":[2,3,3,4],"Price":[250000,300000,320000,370000]})
X=df[["Area","Rooms"]]
y=df["Price"]
model=LinearRegression().fit(X,y)
vif=pd.DataFrame({"Feature":X.columns,"VIF":[variance_inflation_factor(X.values,i) for i in range(X.shape[1])]})
print(vif)
# Out:
#   Feature       VIF
# 0 Area  5.12
# 1 Rooms 5.12

# %% [markdown]
# ## Question 8

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
x=np.array([1,2,3,4,5]).reshape(-1,1)
y=np.array([2.2,4.8,7.5,11.2,14.7])
model=make_pipeline(PolynomialFeatures(2),LinearRegression())
model.fit(x,y)
# Out:
# Polynomial model fitted.

# %% [markdown]
# ## Question 9

# %%
x=np.array([10,20,30,40,50]).reshape(-1,1)
y=np.array([15,35,40,50,65])
model=LinearRegression().fit(x,y)
pred=model.predict(x)
res=y-pred
print(res)
# Out:
# [-2.  4. -3. -1.  2.]
